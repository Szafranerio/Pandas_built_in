# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('/Users/bartlomiejszafran/Desktop/Data/df1',index_col=0)
df2 = pd.read_csv('/Users/bartlomiejszafran/Desktop/Data/df2')
df3 = pd.read_csv('/Users/bartlomiejszafran/Desktop/Data/df3')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
#Nicer version of the same plot
df1['A'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('bmh')
df1['A'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
df1['A'].hist()
# Out:
# <Axes: >

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
df3.plot.scatter(x='a',y='b',c='red',s=50,figsize=(12,3))
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df3['a'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
